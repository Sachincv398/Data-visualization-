# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Counts = df['smoker'].value_counts()
Counts
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
a =[ 'sex','children', 'smoker', 'region']
b=['age', 'bmi','charges']

# %%
for i in a:
    sns.catplot(i, data =df,kind='count')
    plt.show()

# %%
for i in b:
    sns.distplot(df[i],bins =10,kde = False)
    plt.show()

# %%
a =[ 'sex','children', 'smoker', 'region']
b=['age', 'bmi','charges']

# %%
sns.scatterplot(df['age'],df['charges'], data = df)

# %%
sns.scatterplot(df['bmi'],df['charges'], data = df)

# %%
sns.barplot(df['sex'],df['charges'], data = df)

# %%
sns.barplot(df['children'],df['charges'], data = df)

# %%
sns.barplot(df['smoker'],df['charges'], data = df)

# %%
sns.barplot(df['region'],df['charges'], data = df)

# %%
sns.swarmplot(x=df['smoker'], y = df['charges'], hue =df['sex'], data = df)

# %%
plt.figure(figsize =(20,10))
sns.swarmplot(x=df['age'], y = df['charges'], hue =df['smoker'], data = df)

# %%
a =[ 'sex','children', 'smoker', 'region']
b=['age', 'bmi','charges']
sns.scatterplot(x=df['age'], y = df['charges'], hue = df['sex'], data = df)

# %%
sns.scatterplot(x=df['smoker'],y=df['charges'], data = df, color ='k')
